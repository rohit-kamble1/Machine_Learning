# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
os.chdir("E:\pandas")

# %%
df=pd.read_csv("weight-height.csv")
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
sns.distplot(df['Height'],bins=30, color="red")

# %%
sns.jointplot(X,y, data=df, kind='reg')

# %%
sns.pairplot(df)

# %%
sns.kdeplot(df['Height'])

# %%
X=df[["Height"]]*2.54 #>>>>#convert height inches into cm
y=df[["Weight"]]*0.454 #>>>#convert pounds(lbs) into Kg(kilogram)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X,y, test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression(normalize= "True")

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize='True')

# %%
y_pred= lr.predict(X_train)
y_pred[0]
# Out:
# array([69.16764172])

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_train, y_pred))
# Out:
# 30.56521840381165

# %%
from sklearn.metrics import r2_score
print(r2_score(y_train, y_pred))
# Out:
# 0.855545277516119

# %%
sns.pairplot(data=df)

# %%
lr.predict(([[152]])) # enter your height in centimeter and get to know your weight#
# Out:
# array([[50.37007077]])

# %%
plt.scatter(X,y, s=10, color="red", label="Dataset")
plt.scatter(X_train, y_train,s=5, color="green", label="ML_model")
plt.xlabel("Height in Centimeter")
plt.ylabel("Weight in Kilogram")
plt.title("Height and Weight prediction")
plt.legend()
plt.show()
#plt.xlim(120,140)

# %%
lr.fit(X_test, y_test)
y_pred_test=lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred_test)
# Out:
# 31.13825171493596

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred_test)
# Out:
# 0.8580853897078926
